# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarthak-Saini07/pep-python/blob/main/MODULES%20/modules_user.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile calculator.py
print("Calculator module loaded")
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    return a / b
if __name__ == "__main__":
    print(add(1,2))
    print(sub(1,2))
    print(mul(1,2))
    print(div(1,2))
# Out:
# Overwriting calculator.py

# %%
# %%writefile geometry.py

def area(l, b):
    return l * b

def peri(l, b):
    return 2 * (l + b)
# Out:
# Writing geometry.py

# %%
from module_prac import calculator
print(calculator.add(1,4))
print(calculator.subtract(1,4))
print(calculator.multiply(4,2))
print(calculator.divide(2,1))
# Out:
# 5
# -3
# 8
# 2.0

# %%
import geometry as g
print(g.sq_area(5))
print(g.rect_area(5,6))
# Out:
# 25
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_577/167652324.py in <cell line: 0>()
#       1 import geometry as g
#       2 print(g.sq_area(5))
# ----> 3 print(g.rect_area(5,6))
#
# AttributeError: module 'geometry' has no attribute 'rect_area'

# %%
from geometry import sq_area, area
print(sq_area(5))
print(area(5,6))
# Out:
# 25
# 30

# %%
from geometry import *
print(sq_area(5))
print(area(5,6))
# Out:
# 25
# 30

# %%
import math as m
print (m.sqrt(25))
print(m.pow(5,5))
print(m.factorial(5))
print(m.pi)
help(m.sqrt)
# dir(m)
# Out:
# 5.0
# 3125.0
# 120
# 3.141592653589793
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %%
import random
num = [1,2,3,4,5]
print(random.random())
print(random.randint(1,10))
print(random.choice([1,2,3,4,5,6]))
random.shuffle(num)
print(num)
# dir(random)
# Out:
# 0.5130422789303977
# 9
# 6
# [3, 1, 5, 2, 4]

# %%
import datetime
print(datetime.date.today())
print(datetime.datetime.now())
print(datetime.date.today().year)
print(datetime.date.today().month)
print(datetime.date.today().day)
# Out:
# 2026-07-16
# 2026-07-16 05:58:30.927270
# 2026
# 7
# 16

# %%
import statistics
marks = [75,80,100,85,95]
print(statistics.mean(marks))
print(statistics.median(marks))
# Out:
# 87
# 85

# %%
import keyword
print(keyword.kwlist)
print(keyword.iskeyword('if'))
print(keyword.iskeyword('hello'))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# True
# False

# %%
import os
print(os.getcwd())
print(os.listdir())
print(os.mkdir('test'))
print(os.listdir())
print(os.rmdir('test'))
print(os.listdir())
# Out:
# /content
# ['.config', 'geometry.py', '__pycache__', 'calculator.py', 'sample_data']
# None
# ['.config', 'geometry.py', 'test', '__pycache__', 'calculator.py', 'sample_data']
# None
# ['.config', 'geometry.py', '__pycache__', 'calculator.py', 'sample_data']

# %%
import sys
print(sys.path)
print(sys.version)
print(sys.maxsize)
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython']
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 9223372036854775807

# %%
import calculator as c
print(c.add(1,2))
# Out:
# 3

# %%
import calculator
print(calculator.add(1,2))
# Out:
# 3

# %%
import math
# print(math.__file__)
print(math.__doc__)
# Out:
# This module provides access to the mathematical functions
# defined by the C standard.

# %%
pip install numpy

# %%
# !pip install pandas
# pip install matplotlib

# %%
# !pip install matplotlib

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.0.2

# %%
# %%writefile Billing_Structure/calculator.py
print("Calculator module loaded")
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    return a / b
if __name__ == "__main__":
    print(add(1,2))
    print(sub(1,2))
    print(mul(1,2))
    print(div(1,2))
# Out:
# Overwriting Billing_Structure/calculator.py

# %%
# %%writefile Billing_Structure/discount.py
def check_eligible(a):
  if a > 10000:
    return True
  else:
    return False
def dis(a):
  if check_eligible(a):
    return a * 0.1
  else:
    return 0
# Out:
# Overwriting Billing_Structure/discount.py

# %%
# %%writefile Billing_Structure/invoice.py
from calculator import add
from discount import dis
print

# %%
# %%writefile Billing_Structure/tax.py
